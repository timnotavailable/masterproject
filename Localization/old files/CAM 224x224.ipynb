# %%
# %run preprocess.py
# Out:
# Reading and Labelling: 100%|█████████████████████████████████████████████████████████| 192/192 [02:42<00:00,  1.18it/s]
# Preprocessing data finished!

# %%
# %run stress_Res18.py
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  4.43it/s]
# Saved checkpoint: model.ckpt-500
#
# training global_step:500
#
# {'average_acc': 1.0, 'average_precision': 1.0, 'recall': 1.0, 'auc': 1.0, 'confusion_matrix': array([[75,  0],
#        [ 0, 40]], dtype=int64)}
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        75
#            1       1.00      1.00      1.00        40
#
#     accuracy                           1.00       115
#    macro avg       1.00      1.00      1.00       115
# weighted avg       1.00      1.00      1.00       115
#
# training epoch:125, global loss:2.130E-03
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.95it/s]
# Saved checkpoint: model.ckpt-1000
#
# training global_step:1000
#
# ...

# %%
# %run rest_Res18.py
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  4.81it/s]
# Saved checkpoint: model.ckpt-500
#
# training global_step:500
#
# {'average_acc': 1.0, 'average_precision': 1.0, 'recall': 1.0, 'auc': 1.0, 'confusion_matrix': array([[92,  0],
#        [ 0, 23]], dtype=int64)}
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        92
#            1       1.00      1.00      1.00        23
#
#     accuracy                           1.00       115
#    macro avg       1.00      1.00      1.00       115
# weighted avg       1.00      1.00      1.00       115
#
# training epoch:125, global loss:1.148E-04
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  4.94it/s]
# Saved checkpoint: model.ckpt-1000
#
# training global_step:1000
#
# ...

# %%
import tensorboard

# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-c9ccf66a1387168e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-c9ccf66a1387168e");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %reload_ext tensorboard
# %tensorboard --logdir=runs --host localhost
# Out:
# Reusing TensorBoard on port 6006 (pid 27332), started 1 day, 19:21:59 ago. (Use '!kill 27332' to kill it.)
#       <iframe id="tensorboard-frame-4d77b74feed41a93" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4d77b74feed41a93");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !taskkill /im tensorboard.exe /f
del /q %TMP%\.tensorboard-info\*

# %%
# %run test_single.py
# Out:
# {'checkpoint_dir': 'checkpoints/checkpoints_stress_FFC_res18', 'checkpoint_name': 'model.ckpt-10400.pt', 'dataset_dir': '../../../metadata/stress', 'type': 'FFC_res18'}
# ..\..\..\metadata\stress\test_set.csv
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.31it/s]
# MPI test:
# {'average_acc': 0.7111111111111111, 'average_precision': 0.38128654970760234, 'recall': 0.8, 'auc': 0.7428571428571429, 'confusion_matrix': array([[24, 11],
#        [ 2,  8]], dtype=int64)}
#               precision    recall  f1-score   support
#
#            0       0.92      0.69      0.79        35
#            1       0.42      0.80      0.55        10
#
#     accuracy                           0.71        45
#    macro avg       0.67      0.74      0.67        45
# weighted avg       0.81      0.71      0.73        45
#
# ...

# %%
# %run test_single.py  ## res18
# Out:
# {'checkpoint_dir': 'checkpoints/checkpoints_stress_Res18', 'checkpoint_name': 'model.ckpt-2328.pt', 'dataset_dir': '../../../metadata/stress', 'type': 'Res18'}
# ..\..\..\metadata\stress\test_set.csv
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:01<00:00,  1.03it/s]
# MPI test:
# {'average_acc': 0.717948717948718, 'average_precision': 0.308058608058608, 'recall': 0.3, 'auc': 0.5810344827586207, 'confusion_matrix': array([[25,  4],
#        [ 7,  3]], dtype=int64)}
#               precision    recall  f1-score   support
#
#            0       0.78      0.86      0.82        29
#            1       0.43      0.30      0.35        10
#
#     accuracy                           0.72        39
#    macro avg       0.60      0.58      0.59        39
# weighted avg       0.69      0.72      0.70        39
#
# ...

# %%
from pytorch_grad_cam import GradCAM, HiResCAM, ScoreCAM, GradCAMPlusPlus, AblationCAM, XGradCAM, EigenCAM, FullGrad
from pytorch_grad_cam.utils.model_targets import BinaryClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image


from pathlib import Path
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from utils import MPIDataset,save_checkpoint, load_checkpoint,Evaluator
from models.Classifiers import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import skimage.transform
import os

# %%
os.listdir(r"processed data/rest")
# Out:
# ['rest N150655739.pt',
#  'rest N151767359.pt',
#  'rest N151959146.pt',
#  'rest N152063293.pt',
#  'rest N152181072.pt',
#  'rest N152248134.pt',
#  'rest N152353050.pt',
#  'rest N152654657.pt',
#  'rest N152698773.pt',
#  'rest N152741776.pt',
#  'rest N152790751.pt',
#  'rest N152934550.pt',
#  'rest N152972697.pt',
#  'rest N152977401.pt',
#  'rest N153015520.pt',
#  'rest N153075437.pt',
#  'rest N153088966.pt',
#  'rest N153179542.pt',
#  'rest N153217716.pt',
#  'rest N153217721.pt',
#  'rest N153328533.pt',
#  'rest N153410503.pt',
#  'rest N153445767.pt',
#  'rest N153550277.pt',
#  'rest N153567021.pt',
#  'rest N153590801.pt',
#  'rest N153605004.pt',
#  'rest N153626239.pt',
#  'rest N153628207.pt',
#  'rest N153636099.pt',
#  'rest N153717102.pt',
#  'rest N153769053.pt',
#  'rest N153834965.pt',
#  'rest N153905848.pt',
#  'rest N154152815.pt',
#  'rest N154175332.pt',
#  'rest N154231861.pt',
#  'rest N154768091.pt',
#  'rest N155305692.pt',
#  'rest N179253184.pt',
# ...

# %%
def pair_abnormal():
    patient_pt=[]
    for i in os.listdir(r"processed data/rest"):
        name=r"processed data/rest/"+i
        if torch.load(name)["label"]==1:
            rest_pt=i.split()[-1]
            patient_pt.append(rest_pt)            
    return patient_pt

# %%
print(pair_abnormal())
# Out:
# ['N152654657.pt', 'N153445767.pt', 'N153636099.pt', 'N153717102.pt', 'N154768091.pt', 'N181665328.pt', 'N181782520.pt', 'N181996551.pt', 'N182098033.pt', 'N182636179.pt', 'N182825523.pt', 'N182837157.pt', 'N182881350.pt', 'N182908964.pt', 'N183101692.pt', 'N183367293.pt', 'N183408689.pt', 'N183411831.pt', 'N183444016.pt', 'N183609173.pt', 'N183614821.pt', 'N183697394.pt', 'N183863436.pt', 'N183887085.pt', 'N183924138.pt', 'N184181113.pt', 'N184297874.pt', 'N184329353.pt', 'N184335140.pt', 'N184382649.pt', 'N184392758.pt', 'N184438083.pt', 'N184444250.pt', 'N184576644.pt', 'N184607161.pt', 'N184726702.pt', 'N184920484.pt', 'N185034943.pt', 'N185174091.pt', 'N185227889.pt', 'N185326362.pt', 'N185352303.pt', 'N185646735.pt', 'N185851276.pt']

# %%
def input_tensor(patient_pt):
    """
    input:
      patient_pt: string array which contain pt.files, whose stress and rest are all abnormal
    return:
      stress_input, rest_input: arrays which contain stress and rest input tensors
    """
    stress_input=[]
    rest_input=[]
    for i in patient_pt:
        stress_name=r"processed data/stress/stress "+i
        rest_name=r"processed data/rest/rest "+i
        stress_input_tensor=torch.from_numpy(torch.load(stress_name)["image"]).unsqueeze(0).to(device)        
        rest_input_tensor=torch.from_numpy(torch.load(rest_name)["image"]).unsqueeze(0).to(device)
        stress_input.append(stress_input_tensor)
        rest_input.append(rest_input_tensor)    
    
    return stress_input,rest_input

# %%
abnormal_patients=pair_abnormal()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
stress_input,rest_input=input_tensor(abnormal_patients)
print(len(stress_input))
print(len(rest_input))
# Out:
# 44
# 44

# %% [markdown]
# #  FFC 18

# %% [markdown]
# ## Model Preparation

# %%
from cam import *
import os
##
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_rest=FFC_res18()
rest_checkpoint_dir=Path(r"checkpoints/checkpoints_rest_FFC_res18")/"model.ckpt-11070.pt"
rest_checkpoint=torch.load(rest_checkpoint_dir)
model_rest.load_state_dict(rest_checkpoint["model"])  
model_rest.to(device)
model_rest.eval()
rest_target_layers=[model_rest.model.layer4[-1]]

# %%
stress_input,rest_input=input_tensor()
rest_input_tensor=rest_input[0]

# %%
rest_grayscale=gray_scale(model_rest,rest_input_tensor,rest_target_layers,method=0,reshape_transform=True)
# Out:
# tensor([[[[ 3.3970,  7.8710,  3.4606,  ...,  4.9848,  9.4993,  4.4009],
#           [ 3.2218,  3.9348,  0.0000,  ...,  2.5945,  3.5623,  0.0000],
#           [ 2.2567,  2.1778,  0.2392,  ...,  6.3978,  1.7797,  1.5349],
#           ...,
#           [ 2.3274,  2.2669,  1.0461,  ...,  1.1029,  0.7006,  0.7590],
#           [ 1.0350,  0.7703,  0.0000,  ...,  0.0000,  0.0000,  4.3481],
#           [ 2.1401,  0.0000,  0.0000,  ...,  2.4820,  0.6429,  0.2303]],
#
#          [[ 9.6685,  2.7670,  0.0000,  ...,  5.4099,  1.0016,  6.2468],
#           [ 5.2764,  5.2677,  2.0762,  ...,  6.9077,  1.4035, 10.3612],
#           [ 1.8374,  0.9149,  2.9278,  ...,  3.4452,  6.9720,  5.0576],
#           ...,
#           [ 0.0000,  0.5895,  2.4311,  ...,  2.1610,  0.0000,  0.0623],
#           [ 1.8776,  0.0000,  0.8465,  ...,  0.4779,  2.5393,  1.1206],
#           [ 1.4420,  1.7143,  0.0000,  ...,  0.3922,  0.7306,  0.0000]],
#
# ...

# %%
## For rest :model, input tensor, target layers
from cam import *
model_rest = Res18()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
checkpoint_dir=Path(r"checkpoints/checkpoints_rest_Res18")/"model.ckpt-1040.pt"
checkpoint=torch.load(checkpoint_dir)
model_rest.load_state_dict(checkpoint["model"])  
model_rest.to(device)
model_rest.eval()
rest_input_tensor=torch.from_numpy(torch.load(r"processed data/rest/rest N183411831.pt")["image"]).unsqueeze(0).to(device)
rest_target_layers = [model_rest.model.layer4[-1]]

# %%
rest_grayscale_cam=gray_scale(model_rest,rest_input_tensor,rest_target_layers,method=1)
print(rest_grayscale_cam.shape)
# Out:
# tensor([[[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 1.1839, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.5827,  ..., 1.9739, 0.0399, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.4225, 0.0419, 0.1221],
#           [0.0000, 0.0000, 0.0000,  ..., 1.1612, 0.1042, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 2.5276, 0.9736, 0.0000]],
#
#          [[3.9228, 6.3928, 6.4176,  ..., 4.8889, 5.0750, 3.5057],
#           [3.8399, 5.2003, 3.8185,  ..., 1.6522, 2.7603, 0.1928],
# ...

# %%
## For Stress 
model_stress = Res18()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

checkpoint_dir=Path(r"checkpoints/checkpoints_stress_Res18")/"model.ckpt-2328.pt"
checkpoint=torch.load(checkpoint_dir)
model_stress.load_state_dict(checkpoint["model"])  
model_stress.to(device)
model_stress.eval()
stress_input_tensor=torch.from_numpy(torch.load(r"processed data/stress/stress N183411831.pt")["image"]).unsqueeze(0)
stress_target_layers = [model_stress.model.layer4[-1]]

# %%
stress_grayscale_cam=gray_scale(model_stress,stress_input_tensor,stress_target_layers,method=1)
# Out:
# tensor([[[[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 1.4373e-01],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 1.6721e-01],
#           ...,
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 8.7188e-01,
#            1.9382e+00, 2.4483e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 7.3667e-02,
#            0.0000e+00, 2.0941e+00],
#           [0.0000e+00, 7.9724e-01, 2.3883e-02,  ..., 2.9894e-01,
#            6.3769e-01, 1.4896e-01]],
#
#          [[7.1579e-01, 3.9089e-01, 1.0487e+00,  ..., 1.9368e+00,
#            2.1986e+00, 1.6521e+00],
#           [1.5392e-01, 0.0000e+00, 0.0000e+00,  ..., 2.6374e-01,
#            1.0798e+00, 1.0440e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            1.0442e+00, 1.4269e+00],
#           ...,
# ...

# %%
percentile_report(stress_grayscale_cam,rest_grayscale_cam,"DUMP/N183411831.image.bin")
# Out:
# region of ischemia  at stress is 51.8960% , namely reversible perfusion defect
# region of scar at rest is 49.4902%
# region of overlapping is 18.3900%

# %%
for i in range(4):
    rest_grayscale_cam=gray_scale(model_rest,rest_input_tensor,rest_target_layers,method=i)
    stress_grayscale_cam=gray_scale(model_stress,stress_input_tensor,stress_target_layers,method=i)
    percentile_report(stress_grayscale_cam,rest_grayscale_cam,"DUMP/N183411831.image.bin")
# Out:
# tensor([[[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 1.1839, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.5827,  ..., 1.9739, 0.0399, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.4225, 0.0419, 0.1221],
#           [0.0000, 0.0000, 0.0000,  ..., 1.1612, 0.1042, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 2.5276, 0.9736, 0.0000]],
#
#          [[3.9228, 6.3928, 6.4176,  ..., 4.8889, 5.0750, 3.5057],
#           [3.8399, 5.2003, 3.8185,  ..., 1.6522, 2.7603, 0.1928],
# ...

# %% [markdown]
# ### Those below are the experiment details

# %%
model_rest = Res18()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

checkpoint_dir=Path(r"checkpoints/checkpoints_rest_Res18")/"model.ckpt-1040.pt"
checkpoint=torch.load(checkpoint_dir)
model_rest.load_state_dict(checkpoint["model"])  
model_rest.to(device)
model_rest.eval()

## select out some abnormal sample and put it into tensor
input_tensor=torch.from_numpy(torch.load(r"processed data/rest/restN183411831.pt")["image"]).unsqueeze(0).to(device)

target_layers = [model_rest.model.layer4]
# input_tensor = data['image'][23].unsqueeze(0).to(device)


cam=GradCAM(model=model_rest, target_layers=target_layers, use_cuda=False)

targets=[BinaryClassifierOutputTarget(1)]

# You can also pass aug_smooth=True and eigen_smooth=True, to apply smoothing.
rest_grayscale_cam = cam(input_tensor=input_tensor, targets=targets)
# Out:
# tensor([[[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 1.1839, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.5827,  ..., 1.9739, 0.0399, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.4225, 0.0419, 0.1221],
#           [0.0000, 0.0000, 0.0000,  ..., 1.1612, 0.1042, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 2.5276, 0.9736, 0.0000]],
#
#          [[3.9228, 6.3928, 6.4176,  ..., 4.8889, 5.0750, 3.5057],
#           [3.8399, 5.2003, 3.8185,  ..., 1.6522, 2.7603, 0.1928],
# ...

# %%
print(torch.from_numpy(torch.load(r"processed data/rest/restN183411831.pt")["image"]).shape)
print(input_tensor.shape)
# Out:
# torch.Size([3, 224, 224])
# torch.Size([1, 3, 224, 224])

# %%
print(rest_grayscale_cam.shape)
print(type(rest_grayscale_cam))
rest_grayscale_cam=rest_grayscale_cam[0,:]
rest_grayscale_cam/=rest_grayscale_cam.max()
# Out:
# (1, 224, 224)
# <class 'numpy.ndarray'>

# %%
# %matplotlib notebook

# %%
plt.figure()
plt.imshow(rest_grayscale_cam,cmap="Reds")

# %%
rest_grayscale_cam=back_transform(rest_grayscale_cam)
print(np.max(rest_grayscale_cam))
print(np.min(rest_grayscale_cam))
print(np.median(rest_grayscale_cam))
print(rest_grayscale_cam.shape)
print(np.sum(rest_grayscale_cam))
# Out:
# 0.9512005
# 0.0
# 0.46838295
# (15, 36)
# 239.37292

# %%
plt.figure()
plt.imshow(rest_grayscale_cam,cmap="Reds")
plt.axis('off')
# Out:
# (-0.5, 35.5, 14.5, -0.5)

# %%
plt.figure()
restcam_flatten=rest_grayscale_cam.flatten()
n,bins,patches=plt.hist(restcam_flatten)
plt.axvline(x=np.mean(restcam_flatten),ymax=np.max(restcam_flatten),color='red',
            linestyle='--',label='mean value')
plt.axvline(x=np.median(restcam_flatten),ymax=np.max(restcam_flatten),color='blue',
            linestyle='--',label='median value')
plt.axvline(x=np.percentile(restcam_flatten,75),ymax=np.max(restcam_flatten),color='green',
            linestyle='--',label='75 percentile ')
plt.tight_layout()
plt.legend()
plt.show()

# %%
print(np.percentile(restcam_flatten,70))
# Out:
# 0.6095749139785765

# %%
threshold=np.percentile(restcam_flatten,70)
rest_grayscale_cam[rest_grayscale_cam>threshold]=1
rest_grayscale_cam[rest_grayscale_cam<threshold]=0
plt.figure()
plt.imshow(rest_grayscale_cam)
plt.axis('off')
# Out:
# (-0.5, 35.5, 14.5, -0.5)

# %%
from ReadImageBin  import ImageBin,rescale_transform
arr4=ImageBin("DUMP/N183411831.image.bin").combine_4()
area_stress=arr4[2,:,:]
area_rest=arr4[3,:,:]


plt.imshow(area_stress)
plt.axis('off')
# Out:
# (-0.5, 35.5, 14.5, -0.5)

# %%
plt.imshow(area_rest)

# %%
## define in one function
# def

# %% [markdown]
# ## gray scale processing:
# #### normalize to [0,1]
# #### plt.hist
# #### select a threshold for masking
# #### return masked gray scale
# #### invoke image bin, read apm1,apm2
# ####  calculate whole area
# #### calculate stress/ rest area , report those area
# #### single stress=> reversible effect ; single rest=>myocardial scar, typically because of prior infarction ;  observed at rest and stress signifies myocardial scar =>  fixed perfusion defects
# #### report those area

# %%
model_stress = Res18()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

checkpoint_dir=Path(r"checkpoints/checkpoints_stress_Res18")/"model.ckpt-2328.pt"
checkpoint=torch.load(checkpoint_dir)
model_stress.load_state_dict(checkpoint["model"])  
model_stress.to(device)
model_stress.eval()

## select out some abnormal sample and put it into tensor
input_tensor=torch.from_numpy(torch.load(r"processed data/stress/stressN183411831.pt")["image"]).unsqueeze(0)

target_layers = [model_rest.model.layer4]
# input_tensor = data['image'][23].unsqueeze(0).to(device)

cam=GradCAM(model=model_rest, target_layers=target_layers, use_cuda=True)

# You can also use it within a with statement, to make sure it is freed,
# In case you need to re-create it inside an outer loop:
# with GradCAM(model=model, target_layers=target_layers, use_cuda=args.use_cuda) as cam:
#   ...

# We have to specify the target we want to generate
# the Class Activation Maps for.
# If targets is None, the highest scoring category
# will be used for every image in the batch.
# Here we use ClassifierOutputTarget, but you can define your own custom targets
# That are, for example, combinations of categories, or specific outputs in a non standard model.

targets=[BinaryClassifierOutputTarget(1)]

# You can also pass aug_smooth=True and eigen_smooth=True, to apply smoothing.
stress_grayscale_cam = cam(input_tensor=input_tensor, targets=targets)
# Out:
# tensor([[[[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 1.4373e-01],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 1.6721e-01],
#           ...,
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 8.7188e-01,
#            1.9382e+00, 2.4483e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 7.3667e-02,
#            0.0000e+00, 2.0941e+00],
#           [0.0000e+00, 7.9724e-01, 2.3883e-02,  ..., 2.9894e-01,
#            6.3769e-01, 1.4896e-01]],
#
#          [[7.1579e-01, 3.9089e-01, 1.0487e+00,  ..., 1.9368e+00,
#            2.1986e+00, 1.6521e+00],
#           [1.5392e-01, 0.0000e+00, 0.0000e+00,  ..., 2.6374e-01,
#            1.0798e+00, 1.0440e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            1.0442e+00, 1.4269e+00],
#           ...,
# ...

# %%
stress_grayscale_cam=back_transform(stress_grayscale_cam[0,:])
plt.figure()
plt.imshow(stress_grayscale_cam,cmap="Reds")
plt.axis('off')
# Out:
# (-0.5, 35.5, 14.5, -0.5)

# %%
plt.figure()
stresscam_flatten=stress_grayscale_cam.flatten()
n,bins,patches=plt.hist(stresscam_flatten)
plt.axvline(x=np.mean(stresscam_flatten),ymax=np.max(stresscam_flatten),color='red',
            linestyle='--',label='mean value')
plt.axvline(x=np.median(stresscam_flatten),ymax=np.max(stresscam_flatten),color='blue',
            linestyle='--',label='median value')
plt.tight_layout()
plt.legend()
plt.show()

# %%
threshold=np.mean(stresscam_flatten)
stress_grayscale_cam[stress_grayscale_cam>threshold]=1
stress_grayscale_cam[stress_grayscale_cam<threshold]=0
plt.figure()
plt.imshow(stress_grayscale_cam)
plt.axis('off')
# Out:
# (-0.5, 35.5, 14.5, -0.5)

# %%
## percent of ischemia
ischemia_percent=(area_stress*stress_grayscale_cam).sum()/area_stress.sum()   ## single stress
prior_scar_percent=(area_rest*rest_grayscale_cam).sum()/area_rest.sum() ## single rest

infarction_cam=stress_grayscale_cam*rest_grayscale_cam
infarction_percent=(infarction_cam*((area_rest+area_stress)/2)).sum()/((area_rest+area_stress)/2).sum()

print("reversible perfusion defect is {}".format(ischemia_percent))
print("region of decreased perfusion at rest is {}, presumably due to prior scar ".format(prior_scar_percent))
print("persistent perfusion defect is {}".format(infarction_percent))
# Out:
# reversible perfusion defect is 0.47535502910614014
# region of decreased perfusion at rest is 0.49083349108695984, presumably due to prior scar
# persistent perfusion defect is 0.33266645669937134

# %% [markdown]
# ## segmentation map

# %%
SEG_LABELS_LIST=[
        {"id":0,"name":"normal",    "rgb_values":[255,255,255]}, ## white
        {"id":1,"name":"stress",    "rgb_values":[0,0,255]},     ## blue
        {"id":2,"name":"rest",    "rgb_values":[0,255,0]},       ## green
        {"id":3,"name":"overlap",    "rgb_values":[255,0,0]}     ## red        
    ]

def label_img_to_rgb(bi_stress,bi_rest):
    bi_overlap=bi_stress*bi_rest
    ## complementary stress,rest region
    bi_stress=bi_stress-bi_overlap
    bi_rest=bi_rest-bi_overlap
    ## label stress : 1,rest:2 ,overlap:3
    bi_rest*=2
    bi_overlap*=3

    label_img=bi_stress+bi_rest+bi_overlap
    labels=np.unique(label_img)
    label_infos=[l for l in SEG_LABELS_LIST if l['id'] in labels]
    label_img_rgb=np.array([label_img,
                           label_img,
                           label_img]).transpose(1,2,0)
    
    for l in label_infos:
        mask=label_img==l['id']
        label_img_rgb[mask]=l['rgb_values']
    
    return label_img_rgb.astype(np.uint8)

# %%
tt=label_img_to_rgb(stress_grayscale_cam,rest_grayscale_cam)
plt.imshow(tt)
plt.xticks(ticks=np.arange(0,36,2))
plt.yticks(ticks=np.arange(0,15,1))
plt.title(" white: normal \n green : only ischemia \n blue : only scar \n red:fixed tissue(overlap) ")
# Out:
# Text(0.5, 1.0, ' white: normal \n green : only ischemia \n blue : only scar \n red:fixed tissue(overlap) ')

# %%
plt.imshow(stress_grayscale_cam)

# %%
plt.imshow(rest_grayscale_cam)
