# %%
# %run preprocess.py
# Out:
# Reading and Labelling: 100%|█████████████████████████████████████████████████████████| 234/234 [03:47<00:00,  1.03it/s]
# Preprocessing data finished!

# %%
import torch
import os
import random
import numpy as np
import pandas as pd
from pathlib import Path

# %%
metadata_dir='metadata'
processed_dir='processed data'


metadata_dir=Path(metadata_dir)
processed_dir=Path(processed_dir)
traincsv_dir=metadata_dir/"train_set.csv"
train_meta=pd.read_csv(traincsv_dir)
meta_csvdir=metadata_dir/'metadata.csv'
metadata=pd.read_csv(meta_csvdir)

# %%
patient_pat=metadata.loc[0]["filepath"].split('\\')[-1]
print(patient_pat)
patient1='processed data\\'+patient_pat
print(patient1)
# Out:
# N186047663.pt
# processed data\N186047663.pt

# %%
total_normal=[]
total_abnormal=[]
for i in range(len(metadata["filepath"])):
    patient_pat=metadata.loc[i]["filepath"].split('\\')[-1]
    patient='processed data\\'+patient_pat

    data=torch.load(patient)

    if data["label"]==1:
        total_abnormal.append(patient)
    else:
        total_normal.append(patient)

# %%
print(len(total_normal))
print(len(total_abnormal))
# Out:
# 174
# 60

# %%
print(len(total_normal)/len(total_abnormal))
# Out:
# 2.9

# %%
# %run augmentation.py

# %%
train_meta=pd.read_csv(traincsv_dir)

train_normal=[]
train_abnormal=[]

for i in range(len(train_meta["filepath"])):
    patient_pat=train_meta.loc[i]["filepath"].split('\\')
    patient=patient_pat[-1]
    data=torch.load('processed data\\'+patient)

    if data["label"]==1:
        train_abnormal.append(patient)
    else:
        train_normal.append(patient)

print(len(train_normal))
print(len(train_abnormal))
# Out:
# 105
# 105

# %%
# %run mmd_Res18.py
# Out:
# train on  cuda
# pytorch total params 1546
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 16.05it/s]
# Saved checkpoint: model.ckpt-100
#
# training global_step:100
#
# {'average_acc': 0.49047619047619045, 'average_precision': 0.0, 'Sensitivity': 0.0, 'auc': 0.49047619047619045, 'confusion_matrix': array([[103,   2],
#        [105,   0]], dtype=int64), 'specificity': 0.9809523809523809}
#               precision    recall  f1-score   support
#
#            0       0.50      0.98      0.66       105
#            1       0.00      0.00      0.00       105
#
#     accuracy                           0.49       210
#    macro avg       0.25      0.49      0.33       210
# weighted avg       0.25      0.49      0.33       210
#
# training epoch:25, global loss:7.902E+00
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 13.90it/s]
# Saved checkpoint: model.ckpt-200
#
# ...

# %%
# %run mmd_Res34.py
# Out:
# train on  cuda
# pytorch total params 1546
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 14.33it/s]
# Saved checkpoint: model.ckpt-100
#
# training global_step:100
#
# {'average_acc': 0.5095238095238095, 'average_precision': 0.505, 'Sensitivity': 0.9619047619047619, 'auc': 0.5095238095238095, 'confusion_matrix': array([[  6,  99],
#        [  4, 101]], dtype=int64), 'specificity': 0.05714285714285714}
#               precision    recall  f1-score   support
#
#            0       0.60      0.06      0.10       105
#            1       0.51      0.96      0.66       105
#
#     accuracy                           0.51       210
#    macro avg       0.55      0.51      0.38       210
# weighted avg       0.55      0.51      0.38       210
#
# training epoch:25, global loss:8.208E+00
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 15.27it/s]
# ...

# %%
# %run mmd_Res50.py
# Out:
# train on  cuda
# pytorch total params 6154
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 13.16it/s]
# Saved checkpoint: model.ckpt-100
#
# training global_step:100
#
# {'average_acc': 0.4142857142857143, 'average_precision': 0.4117647058823529, 'Sensitivity': 0.4, 'auc': 0.41428571428571426, 'confusion_matrix': array([[45, 60],
#        [63, 42]], dtype=int64), 'specificity': 0.42857142857142855}
#               precision    recall  f1-score   support
#
#            0       0.42      0.43      0.42       105
#            1       0.41      0.40      0.41       105
#
#     accuracy                           0.41       210
#    macro avg       0.41      0.41      0.41       210
# weighted avg       0.41      0.41      0.41       210
#
# training epoch:25, global loss:2.984E+00
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 13.69it/s]
# ...

# %%
# %run mmd_Naive_CNN.py
# Out:
# train on  cpu
# pytorch total params 55
#   0%|                                                                                            | 0/4 [00:02<?, ?it/s]
# Error executing job with overrides: []
# Traceback (most recent call last):
#   File "E:\thesiscopy\thesis\step5\mmd\mmd_Naive_CNN.py", line 127, in train_model
#     logits_batch=classifier(mpi_image,age,TID,sr_ratio)
#   File "C:\Users\Guo\Anaconda\envs\MPI\lib\site-packages\torch\nn\modules\module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "E:\thesiscopy\thesis\step5\mmd\models\Classifiers.py", line 224, in forward
#     x=self.fcnn(x)
#   File "C:\Users\Guo\Anaconda\envs\MPI\lib\site-packages\torch\nn\modules\module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "C:\Users\Guo\Anaconda\envs\MPI\lib\site-packages\torch\nn\modules\container.py", line 217, in forward
#     input = module(input)
# ...

# %%
# %run mmd_FFC_res18.py
# Out:
# train on  cuda
# pytorch total params 1546
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  8.78it/s]
# Saved checkpoint: model.ckpt-500
#
# training global_step:500
#
# {'average_acc': 0.49047619047619045, 'average_precision': 0.49056603773584906, 'Sensitivity': 0.49523809523809526, 'auc': 0.4904761904761905, 'confusion_matrix': array([[51, 54],
#        [53, 52]], dtype=int64), 'specificity': 0.4857142857142857}
#               precision    recall  f1-score   support
#
#            0       0.49      0.49      0.49       105
#            1       0.49      0.50      0.49       105
#
#     accuracy                           0.49       210
#    macro avg       0.49      0.49      0.49       210
# weighted avg       0.49      0.49      0.49       210
#
# training epoch:125, global loss:1.610E+00
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  9.09it/s]
# ...

# %%
# %run mmd_FFC_res26.py
# Out:
# train on  cuda
# pytorch total params 6154
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  5.99it/s]
# Saved checkpoint: model.ckpt-500
#
# training global_step:500
#
# {'average_acc': 0.5714285714285714, 'average_precision': 0.5757575757575758, 'Sensitivity': 0.5428571428571428, 'auc': 0.5714285714285714, 'confusion_matrix': array([[63, 42],
#        [48, 57]], dtype=int64), 'specificity': 0.6}
#               precision    recall  f1-score   support
#
#            0       0.57      0.60      0.58       105
#            1       0.58      0.54      0.56       105
#
#     accuracy                           0.57       210
#    macro avg       0.57      0.57      0.57       210
# weighted avg       0.57      0.57      0.57       210
#
# training epoch:125, global loss:7.108E-01
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  5.87it/s]
# ...

# %%
# %run mmd_FFC_res34.py
# Out:
# train on  cuda
# pytorch total params 1546
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  4.71it/s]
# Saved checkpoint: model.ckpt-500
#
# training global_step:500
#
# {'average_acc': 0.5761904761904761, 'average_precision': 0.5727272727272728, 'Sensitivity': 0.6, 'auc': 0.5761904761904763, 'confusion_matrix': array([[58, 47],
#        [42, 63]], dtype=int64), 'specificity': 0.5523809523809524}
#               precision    recall  f1-score   support
#
#            0       0.58      0.55      0.57       105
#            1       0.57      0.60      0.59       105
#
#     accuracy                           0.58       210
#    macro avg       0.58      0.58      0.58       210
# weighted avg       0.58      0.58      0.58       210
#
# training epoch:125, global loss:2.079E+00
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  4.89it/s]
# ...

# %%
from models.Classifiers import mmd_FFC_res34
import torch
model=mmd_FFC_res34(pretrained_path="checkpoints//checkpoints_FFC_res34//model.ckpt-1400.pt")
print(model)
# Out:
# mmd_FFC_res34(
#   (model): FFCResNet(
#     (conv1): Conv2d(4, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): Identity()
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): FFC_BN_ACT(
#           (ffc): FFC(
#             (convl2l): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (convl2g): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (convg2l): Identity()
#             (convg2g): Identity()
#           )
#           (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (bn_g): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_l): ReLU(inplace=True)
#           (act_g): ReLU(inplace=True)
#         )
# ...

# %%
import tensorboard
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
# Reusing TensorBoard on port 6006 (pid 28952), started 10:02:59 ago. (Use '!kill 28952' to kill it.)
#       <iframe id="tensorboard-frame-2c79111c8b7e64fc" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-2c79111c8b7e64fc");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %reload_ext tensorboard
# %tensorboard --logdir=runs --host localhost
# Out:
#       <iframe id="tensorboard-frame-459aee5ab77450b4" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-459aee5ab77450b4");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !taskkill /im tensorboard.exe /f
del /q %TMP%\.tensorboard-info\*

# %%
# %run test_mmd.py
# Out:
# mmd_Res18
# D:\thesis\step5\mmd\checkpoints\checkpoints_mmd_Res18\model.ckpt-2700.pt
# ..\..\..\metadata\test_set.csv
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 30.26it/s]
# MPI test:
# {'average_acc': 0.6595744680851063, 'average_precision': 0.4444444444444444, 'Sensitivity': 0.5714285714285714, 'auc': 0.6341991341991342, 'confusion_matrix': array([[23, 10],
#        [ 6,  8]], dtype=int64), 'specificity': 0.696969696969697}
# average accuracy is : 0.6595744680851063
# average precision is : 0.4444444444444444
# recall is : 0.5714285714285714
# Area Under the Receiver Operating Characteristic Curve (ROC AUC) is : 0.6341991341991342
#               precision    recall  f1-score   support
#
#            0       0.79      0.70      0.74        33
#            1       0.44      0.57      0.50        14
#
#     accuracy                           0.66        47
#    macro avg       0.62      0.63      0.62        47
# ...
